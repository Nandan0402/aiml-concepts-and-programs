# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandan0402/aiml-concepts-and-programs/blob/main/AIML_CONCEPTS_AND_PROGRAMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To swap 2 numbers

# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))

print(f"Before swapping: b={a} and d={b}")

a,b=b,a

print(f"After swapping: b={a} and d={b}")
# Out:
# Enter the first number:12
# Enter the second number:23
# Before swapping: b=12 and d=23
# After swapping: b=23 and d=12

# %% [markdown]
# To check if a number is even or odd

# %%
num=int(input("Enter a number:"))

if num%2 == 0:
  print(f"{num} is even")
else:
  print(f"{num} is odd")
# Out:
# Enter a number:987645
# 987645 is odd

# %% [markdown]
# Find the largest of 3 numbers

# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
c=int(input("Enter the third number:"))
d=int(input("Enter the fourth number:"))
if a>=b and a>=c and a>=d:
  print("Largest number is:",a)
elif b>=a and b>=c and b>=d:
  print("Largest number is:",b)
elif c>=a and c>=b and c>=d:
  print("Largest number is:",c)
else:
  print("Largest number is:",d)
# Out:
# Enter the first number:1
# Enter the second number:2
# Enter the third number:4
# Enter the fourth number:5
# Largest number is: 5

# %% [markdown]
# To check if a string is palindrome

# %%
def is_palindrome(text):
  cleaned=text.replace(""," ").lower()
  return cleaned==cleaned[::-1]
user_input=input("Enter a word or number:")
if is_palindrome(user_input):
  print(f"{user_input} is a palindrome")
else:
  print(f"{user_input} is not a palindrome")
# Out:
# Enter a word or number:RACECAR
# RACECAR is a palindrome

# %% [markdown]
# To check if a year is a leap year

# %%
year=int(input("Enter a year:"))
if (year%400==0):
  print(year,"is a leap year")
elif (year%100==0):
  print(year,"is not a leap year")
elif (year%4==0):
  print(year,"is a leap year")
else:
  print(year,"is Not a leap year")
# Out:
# Enter a year:2020
# 2020 is a leap year

# %% [markdown]
# To count the vowels/consonants

# %%
text=input("Enter a string:")
consonants="bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ"
count=0

for char in text:
  if char in consonants:
    count+=1

print(f"number of consonants:{count}")
# Out:
# Enter a string:messi
# number of consonants:3

# %% [markdown]
# To read the csv file and print the rows

# %%
import csv
from google.colab import files
uploaded = files.upload()
filename=list(uploaded.keys())[0]
with open(filename,newline='')as file:
  reader=csv.reader(file)
  for row in reader:
      print(row)
# Out:
#      <input type="file" id="files-5086c6e4-c36a-4740-bfa1-0eae19fd4fc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5086c6e4-c36a-4740-bfa1-0eae19fd4fc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# To combine two lists into a dictionary using a zip function

# %%
keys=["name","age","city"]
values=["Abhinav","20","Bangalore"]
my_dict=dict(zip(keys,values))
print(my_dict)
# Out:
# {'name': 'Abhinav', 'age': '20', 'city': 'Bangalore'}

# %% [markdown]
# Webscrapping using beautiful soup library

# %%
import requests
from bs4 import BeautifulSoup

url="https://www.youtube.com/watch?v=SHVAXf7zVA0&t=695s"
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
links=soup.find_all("a")
for link in links:
  href=link.get("href")
  if href:
    print(href)
# Out:
# /
# /
# https://www.youtube.com/about/
# https://www.youtube.com/about/press/
# https://www.youtube.com/about/copyright/
# /t/contact_us/
# https://www.youtube.com/creators/
# https://www.youtube.com/ads/
# https://developers.google.com/youtube
# /t/terms
# /t/privacy
# https://www.youtube.com/about/policies/
# https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# /new
# https://tv.youtube.com/learn/nflsundayticket

# %% [markdown]
# To count the number of lines in a file

# %%
from google.colab import files
uploaded=files.upload()
filename=list(uploaded.keys())[0]
count=0
with open(filename,"r")as file:
  for line in file:
    count+=1
print("Number of lines in a file:",count)
# Out:
#      <input type="file" id="files-8daefffa-3da9-46de-b23e-f7055eabb519" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8daefffa-3da9-46de-b23e-f7055eabb519">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Use a list comprehension create a list of squares of even numbers from 1 to 50

# %%
squares=[x**2 for x in range(1,51)if x % 2==0]
print(squares)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400, 484, 576, 676, 784, 900, 1024, 1156, 1296, 1444, 1600, 1764, 1936, 2116, 2304, 2500]

# %% [markdown]
# Program to print fibonacci series

# %%
def fibonacci(n):
  a=0
  b=1

  for i in range(n):
    print(a,end="")
    a,b=b,a+b
num=int(input("Enter how many terms:"))
fibonacci(num)
# Out:
# Enter how many terms:5
# 01123

# %% [markdown]
# Write a class for a bank account with deposit and withdrawal fucntionality

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited: {amount}. New Balance: {self.balance}")
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        if amount > 0:
            if self.balance >= amount:
                self.balance -= amount
                print(f"Withdrawn: {amount}.New Balance: {self.balance}")
            else:
                print("Insufficent balance")
        else:
            print("Withdrawal amount must be positive")
    def get_balance(self):
        return self.balance

account = BankAccount("Abhinav",100000)
account.deposit(5500)
account.withdraw(2090)
account.withdraw(2000000)
print("Final Balance:", account.get_balance())
# Out:
# Deposited: 5500. New Balance: 105500
# Withdrawn: 2090.New Balance: 103410
# Insufficent balance
# Final Balance: 103410

# %% [markdown]
# Implement a basic student managment system using object oreinted programming

# %%
class Student:
  def __init__(self,student_id,name,age,course):
    self.student_id=student_id
    self.name=name
    self.age=age
    self.course=course
  def display(self):
    print(f"ID:{self.student_id},Name:{self.name},Age:{self.age},Course:{self.course}")

class StudentManagmentSystem:
  def __init__(self):
    self.students=[]
  def add_student(self,student):
    self.students.append(student)
    print(f"Student{student.name}added successfully")

  def display_all(self):
    if not self.students:
      print("No students found")
    else:
      print("\nStudent List:")
      for student in self.students:
        student.display()

  def search_student(self,student_id):
    for student in self.students:
      if student.student_id==student_id:
        print("Student Found:")
        student.display()
        return
    print("Student not found")

  def remove_student(self,student_id):
    for student in self.students:
      if student.student_id==student_id:
        self.students.remove(student)
        print(f"Student{student.name}removed successfully")
        return
    print("Student not found")

sms=StudentManagmentSystem()

s1=Student(1,"Abhinav",20,"Comouter Science")
s2=Student(2,"Aswin",21,"MBBS")

sms.add_student(s1)
sms.add_student(s2)

sms.display_all()

sms.search_student(1)
sms.search_student(1)

sms.remove_student(2)
sms.display_all()
# Out:
# StudentAbhinavadded successfully
# StudentAswinadded successfully
#
# Student List:
# ID:1,Name:Abhinav,Age:20,Course:Comouter Science
# ID:2,Name:Aswin,Age:21,Course:MBBS
# Student Found:
# ID:1,Name:Abhinav,Age:20,Course:Comouter Science
# Student not found
# StudentAswinremoved successfully
#
# Student List:
# ID:1,Name:Abhinav,Age:20,Course:Comouter Science

# %% [markdown]
# To find a pairs of numbers with a given list of numbers

# %%
numbers=[2,4,3,5,7,8,9]
target=10
pairs=[]
for num1 in numbers:
  for num2 in numbers:
    if num1!=num2 and num1+num2==target:
      pair=(num1,num2)
      if(num2,num1) not in pairs:
        pairs.append(pair)
print("Pairs with sum",target,"are:",pairs)
# Out:
# Pairs with sum 10 are: [(2, 8), (3, 7)]
